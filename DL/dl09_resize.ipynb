# %%
import platform
import matplotlib.pyplot as plt

import torch
import torchvision.transforms.v2 as transforms
import torchvision.io as io

# %%
# OS에 따른 한글 폰트 설정
if platform.system() == 'Windows':
    plt.rc('font', family='Malgun Gothic')  # 윈도우: 맑은 고딕
elif platform.system() == 'Darwin':
    plt.rc('font', family='AppleGothic')    # 맥: 애플 고딕
else:
    plt.rc('font', family='NanumBarunGothic') # 리눅스

# 마이너스 기호 깨짐 방지
plt.rc('axes', unicode_minus=False)

# %%
# 이미지 경로
image_path = "data/four.jpg"  # 이미지 경로

# 1. PyTorch를 사용해 이미지를 텐서 형태로 직접 로드 (C, H, W / uint8)
original_tensor = io.read_image(image_path)
c, h, w = original_tensor.shape
print(f"Original shape (C, H, W): {original_tensor.shape}")

# 2. PyTorch Transform을 사용한 리사이즈 (224x224)
resize_transform = transforms.Resize((224, 224), antialias=True)
resized_tensor = resize_transform(original_tensor)

# 3. Matplotlib 시각화를 위해 (C, H, W) -> (H, W, C)로 넘파이/텐서 차원 변경 (.permute 사용)
original_display = original_tensor.permute(1, 2, 0).numpy()
resized_display = resized_tensor.permute(1, 2, 0).numpy()

# 4. 시각화
plt.figure(figsize=(10, 5))

# 원본 이미지
plt.subplot(1, 2, 1)
plt.imshow(original_display)
plt.title(f"Original(원본) Image ({w}x{h})")
plt.axis("off")

# 리사이즈 이미지
plt.subplot(1, 2, 2)
plt.imshow(resized_display)
plt.title("Resized Image (224x224)")
plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# Original shape (C, H, W): torch.Size([1, 20, 20])

# %%
import os
print(os.getcwd())          # 현재 Jupyter가 어느 폴더를 기준으로 돌고 있는지 확인
print(os.path.exists("data/four.jpg"))  # 그 기준으로 이 경로에 파일이 실제 있는지 확인
print(os.listdir("data"))   # data 폴더 안에 뭐가 들어있는지 확인 (data 폴더가 있다면)
# Out:
# c:\sk-encoa\dl_workspace
# False
# ['cifar-10-batches-py', 'cifar-10-python.tar.gz', 'MNIST']
